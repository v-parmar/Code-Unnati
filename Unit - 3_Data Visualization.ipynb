# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
x = [1,2,3]
y = [2,4,1]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My First Graph')
plt.show()

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(x)

plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0, 10, 0.1)
y = np.cos(x)

plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0, 10, 0.1)
y = np.tan(x)

plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
# plot-1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,6,1)
plt.plot(x,y)

# plot-2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,6,2)
plt.plot(x,y)

# plot-3
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,6,3)
plt.plot(x,y)

# plot-4
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,6,4)
plt.plot(x,y)

# plot-5
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,6,5)
plt.plot(x,y)

# plot-6
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,6,6)
plt.plot(x,y)

# %%
ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
# change the marker symbol

from turtle import color


ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
# change the line style

ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker = '*', linestyle = 'dotted')
plt.show()

# %%
# change the line color

ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker = '+', color='r')
plt.show()

# %%
# Adding title and labelling the axes in the graph

x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]

plt.bar(x,y)

plt.title("My first bar graph")

plt.xlabel("Time(hr)")
plt.ylabel("Position(km)")

plt.show()

# %%
y1 = [2, 3, 4.5]
y2 = [1, 1.5, 5]

plt.plot(y1)
plt.plot(y2)

plt.legend(["Vadodara", "Surat"], loc="best")

plt.show()

# %%
y1 = [2, 3, 4.5]
y2 = [1, 1.5, 5]

plt.plot(y1)
plt.plot(y2)

plt.legend(["Vadodara", "Surat"], loc="lower right")

plt.show()

# %%
data = np.random.normal(170, 10, 250)
print(data)

plt.hist(data);
plt.show()

plt.hist(data, bins=40);
plt.show()
# Out:
# [189.00223261 167.09325004 182.37772295 170.46873945 147.97779732
#  174.20230945 141.75574003 182.61351273 179.87598463 168.16915893
#  162.12031422 160.59806836 162.94968398 169.45301659 149.10218546
#  183.14745383 182.22919661 171.43349914 184.72669173 172.99778861
#  159.49014922 179.92989823 155.26264144 175.25047755 164.42054422
#  173.14014163 172.78242536 160.31310923 158.78996345 181.35209216
#  160.43066961 170.58734871 174.85067325 160.52520866 185.05891398
#  168.78234923 167.33715933 157.84896036 166.16600027 167.56895942
#  182.42663204 151.73363397 169.2512032  163.5252857  163.59248481
#  172.85646252 176.26648162 167.54719108 178.72838004 167.56175791
#  182.54785733 159.421916   175.77641152 146.71696555 154.3424961
#  160.98156782 165.87395576 161.11441181 164.48888757 178.09071794
#  179.91215795 163.7065828  178.77794138 181.54618611 171.45575273
#  170.94461088 157.33533794 151.74201425 178.04296143 167.07380207
# ...

# %%
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4), arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('local minimum', xy=(5*np.pi, -1), xytext=(2, -6), arrowprops=dict(arrowstyle="wedge", connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
w = 4
h = 3
d = 70

plt.figure(figsize=(w, h), dpi=d)
plt.axis([0, 5, 0, 5])
x = [0, 3, 5]
y = [1, 4, 3.5]
label_x = 1
label_y = 4
arrow_x = 3
arrow_y = 4

arrow_properties = dict(
    facecolor="black", width=0.5,
    headwidth=5, shrink=0.1)

plt.annotate(
    "maximum", xy=(arrow_x, arrow_y),
    xytext=(label_x, label_y),
    arrowprops=arrow_properties)
plt.plot(x, y)

# %%
#syntax
fig = plt.figure()
ax = plt.axes(projection ='3d')

# %%
fig = plt.figure()

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax.plot3D(x, y, z, 'blue')
ax.set_title('3D line plot')
plt.show()

# %%
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']

data = [23, 17, 35, 29, 12, 41]

fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)

plt.show()
